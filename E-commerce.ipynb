# %%
# !pip install pyquery
# Out:
# Collecting pyquery
#   Downloading https://files.pythonhosted.org/packages/78/43/95d42e386c61cb639d1a0b94f0c0b9f0b7d6b981ad3c043a836c8b5bc68b/pyquery-1.4.1-py2.py3-none-any.whl
# Collecting cssselect>0.7.9
#   Downloading https://files.pythonhosted.org/packages/3b/d4/3b5c17f00cce85b9a1e6f91096e1cc8e8ede2e1be8e96b87ce1ed09e92c5/cssselect-1.1.0-py2.py3-none-any.whl
# Requirement already satisfied: lxml>=2.1 in /usr/local/lib/python3.6/dist-packages (from pyquery) (4.2.6)
# Installing collected packages: cssselect, pyquery
# Successfully installed cssselect-1.1.0 pyquery-1.4.1

# %%
import requests
from pyquery import PyQuery as pq

# %%
response = requests.get("https://webscraper.io/test-sites/\
e-commerce/allinone")
doc = pq(response.text)

# %%
dataList = []
doc.make_links_absolute(base_url=response.url)
for eachMainDoc in doc("#side-menu > li:nth-child(n+2) > a").items():
  # print(eachMainDoc.attr("href"))
  mainRes = requests.get(eachMainDoc.attr("href"))
  mainDoc = pq(mainRes.text)
  mainDoc.make_links_absolute(base_url=mainRes.url)
  for eachSubDoc in mainDoc("#side-menu > li.active > ul > li > a").items():
    print(eachSubDoc.attr("href"))
    subRes = requests.get(eachSubDoc.attr("href"))
    subDoc = pq(subRes.text)
    #level 2
    for eachItem in subDoc(".test-site .thumbnail").items():
      dataDict = {}
      dataDict["title"] = eachItem("h4>.title").text()
      dataDict["price"] = eachItem("h4.price").text()
      dataDict["stars"] = len(eachItem("span.glyphicon-star"))
      dataList.append(dataDict)
      # print(eachItem("h4>.title").text())
      # print(eachItem("h4.price").text())
      # print(len(eachItem("span.glyphicon-star")))
      # print((eachItem(".ratings>p:nth-child(2)").attr("data-rating"))
# Out:
# https://webscraper.io/test-sites/e-commerce/allinone/computers/laptops
# https://webscraper.io/test-sites/e-commerce/allinone/computers/tablets
# https://webscraper.io/test-sites/e-commerce/allinone/phones/touch

# %%
dataList
# Out:
# [{'price': '$295.99', 'stars': 3, 'title': 'Asus VivoBook X4...'},
#  {'price': '$299.00', 'stars': 2, 'title': 'Prestigio SmartB...'},
#  {'price': '$299.00', 'stars': 4, 'title': 'Prestigio SmartB...'},
#  {'price': '$306.99', 'stars': 3, 'title': 'Aspire E1-510'},
#  {'price': '$321.94', 'stars': 3, 'title': 'Lenovo V110-15IA...'},
#  {'price': '$356.49', 'stars': 2, 'title': 'Lenovo V110-15IA...'},
#  {'price': '$364.46', 'stars': 1, 'title': 'Hewlett Packard...'},
#  {'price': '$372.70', 'stars': 2, 'title': 'Acer Aspire 3 A3...'},
#  {'price': '$379.94', 'stars': 2, 'title': 'Acer Aspire A315...'},
#  {'price': '$379.95', 'stars': 4, 'title': 'Acer Aspire ES1-...'},
#  {'price': '$391.48', 'stars': 4, 'title': 'Acer Aspire 3 A3...'},
#  {'price': '$393.88', 'stars': 3, 'title': 'Acer Aspire 3 A3...'},
#  {'price': '$399.00', 'stars': 1, 'title': 'Asus VivoBook Ma...'},
#  {'price': '$399.99', 'stars': 4, 'title': 'Asus VivoBook E5...'},
#  {'price': '$404.23', 'stars': 1, 'title': 'Lenovo ThinkPad...'},
#  {'price': '$408.98', 'stars': 4, 'title': 'Acer Aspire 3 A3...'},
#  {'price': '$409.63', 'stars': 3, 'title': 'Lenovo V110-15IS...'},
#  {'price': '$410.46', 'stars': 4, 'title': 'Acer Aspire ES1-...'},
#  {'price': '$410.66', 'stars': 4, 'title': 'Asus VivoBook 15...'},
#  {'price': '$416.99', 'stars': 2, 'title': 'Packard 255 G2'},
#  {'price': '$433.30', 'stars': 1, 'title': 'Asus EeeBook R41...'},
#  {'price': '$436.29', 'stars': 1, 'title': 'Acer Aspire 3 A3...'},
#  {'price': '$436.29', 'stars': 1, 'title': 'Acer Aspire ES1-...'},
#  {'price': '$439.73', 'stars': 4, 'title': 'Acer Extensa 15...'},
#  {'price': '$454.62', 'stars': 1, 'title': 'Acer Aspire ES1-...'},
#  {'price': '$454.73', 'stars': 2, 'title': 'Lenovo V110-15IS...'},
#  {'price': '$457.38', 'stars': 3, 'title': 'Acer Aspire A315...'},
#  {'price': '$465.95', 'stars': 1, 'title': 'Lenovo V110-15IK...'},
#  {'price': '$468.56', 'stars': 3, 'title': 'Asus VivoBook 15...'},
#  {'price': '$469.10', 'stars': 3, 'title': 'Acer Aspire ES1-...'},
#  {'price': '$484.23', 'stars': 3, 'title': 'Lenovo V510 Blac...'},
#  {'price': '$485.90', 'stars': 3, 'title': 'Acer Aspire ES1-...'},
#  {'price': '$487.80', 'stars': 2, 'title': 'Lenovo V510 Blac...'},
#  {'price': '$488.64', 'stars': 3, 'title': 'Acer Swift 1 SF1...'},
#  {'price': '$488.78', 'stars': 4, 'title': 'Dell Vostro 15'},
#  {'price': '$494.71', 'stars': 4, 'title': 'Acer Aspire 3 A3...'},
#  {'price': '$497.17', 'stars': 1, 'title': 'Dell Vostro 15 (...'},
#  {'price': '$498.23', 'stars': 3, 'title': 'Lenovo V510 Blac...'},
#  {'price': '$520.99', 'stars': 2, 'title': 'HP 250 G3'},
#  {'price': '$564.98', 'stars': 2, 'title': 'Acer Spin 5'},
#  {'price': '$577.99', 'stars': 2, 'title': 'HP 350 G1'},
#  {'price': '$581.99', 'stars': 1, 'title': 'Aspire E1-572G'},
#  {'price': '$609.99', 'stars': 1, 'title': 'Pavilion'},
#  {'price': '$679.00', 'stars': 2, 'title': 'Acer Aspire A515...'},
#  {'price': '$679.00', 'stars': 2, 'title': 'Dell Inspiron 15'},
#  {'price': '$729.00', 'stars': 1, 'title': 'Asus VivoBook S1...'},
#  {'price': '$739.99', 'stars': 4, 'title': 'ProBook'},
#  {'price': '$745.99', 'stars': 3, 'title': 'Inspiron 15'},
#  {'price': '$799.00', 'stars': 2, 'title': 'Asus ROG STRIX G...'},
#  {'price': '$809.00', 'stars': 1, 'title': 'Acer Nitro 5 AN5...'},
#  {'price': '$899.00', 'stars': 1, 'title': 'Asus ROG STRIX G...'},
#  {'price': '$999.00', 'stars': 3, 'title': 'Lenovo ThinkPad...'},
#  {'price': '$1033.99', 'stars': 2, 'title': 'ThinkPad Yoga'},
#  {'price': '$1096.02', 'stars': 4, 'title': 'Lenovo ThinkPad...'},
#  {'price': '$1098.42', 'stars': 1, 'title': 'Dell Inspiron 15...'},
#  {'price': '$1099.00', 'stars': 4, 'title': 'MSI GL72M 7RDX'},
#  {'price': '$1099.00', 'stars': 1, 'title': 'MSI GL72M 7RDX'},
#  {'price': '$1101.83', 'stars': 2, 'title': 'Asus ROG Strix G...'},
#  {'price': '$1102.66', 'stars': 1, 'title': 'Dell Latitude 52...'},
#  {'price': '$1110.14', 'stars': 3, 'title': 'Dell Latitude 54...'},
#  {'price': '$1112.91', 'stars': 4, 'title': 'Lenovo Legion Y5...'},
#  {'price': '$1114.55', 'stars': 1, 'title': 'Toshiba Portege...'},
#  {'price': '$1123.87', 'stars': 2, 'title': 'Acer Predator He...'},
#  {'price': '$1123.87', 'stars': 2, 'title': 'Acer Aspire 7 A7...'},
#  {'price': '$1124.20', 'stars': 3, 'title': 'Dell Inspiron 17...'},
#  {'price': '$1133.82', 'stars': 4, 'title': 'Dell Latitude 54...'},
#  {'price': '$1133.91', 'stars': 1, 'title': 'Lenovo Legion Y5...'},
#  {'price': '$1139.54', 'stars': 3, 'title': 'Asus AsusPro Adv...'},
#  {'price': '$1140.62', 'stars': 3, 'title': 'Acer Nitro 5 AN5...'},
#  {'price': '$1143.40', 'stars': 4, 'title': 'Dell Latitude 54...'},
#  {'price': '$1144.20', 'stars': 1, 'title': 'Dell Inspiron 15...'},
#  {'price': '$1144.40', 'stars': 3, 'title': 'Dell Latitude 55...'},
#  {'price': '$1149.00', 'stars': 3, 'title': 'Lenovo Legion Y5...'},
#  {'price': '$1149.00', 'stars': 1, 'title': 'MSI GP62M 7RDX L...'},
#  {'price': '$1149.73', 'stars': 2, 'title': 'Lenovo Yoga 720...'},
#  {'price': '$1154.04', 'stars': 1, 'title': 'Toshiba Portege...'},
#  {'price': '$1170.10', 'stars': 1, 'title': 'Acer TravelMate...'},
#  {'price': '$1178.19', 'stars': 3, 'title': 'Dell Latitude 55...'},
#  {'price': '$1178.99', 'stars': 1, 'title': 'ThinkPad T540p'},
#  {'price': '$1179.00', 'stars': 1, 'title': 'MSI GS63 7RD Ste...'},
#  {'price': '$1187.88', 'stars': 3, 'title': 'Dell Latitude 54...'},
#  {'price': '$1187.98', 'stars': 3, 'title': 'Acer Predator He...'},
#  {'price': '$1199.00', 'stars': 1, 'title': 'MSI GL62M 7REX'},
#  {'price': '$1199.00', 'stars': 2, 'title': 'MSI GL62M 7REX2'},
#  {'price': '$1199.73', 'stars': 3, 'title': 'Lenovo Yoga 910...'},
#  {'price': '$1203.41', 'stars': 4, 'title': 'Toshiba Portege...'},
#  {'price': '$1212.16', 'stars': 4, 'title': 'Lenovo IdeaPad M...'},
#  {'price': '$1221.58', 'stars': 1, 'title': 'Acer Predator He...'},
#  {'price': '$1223.99', 'stars': 3, 'title': 'ThinkPad Yoga'},
#  {'price': '$1235.49', 'stars': 2, 'title': 'Asus VivoBook Pr...'},
#  {'price': '$1238.37', 'stars': 2, 'title': 'Dell Latitude 54...'},
#  {'price': '$1239.20', 'stars': 1, 'title': 'Asus ZenBook UX5...'},
#  {'price': '$1244.99', 'stars': 3, 'title': 'ThinkPad X230'},
#  {'price': '$1259.00', 'stars': 4, 'title': 'Asus ROG Strix G...'},
#  {'price': '$1260.13', 'stars': 4, 'title': 'Apple MacBook Ai...'},
#  {'price': '$1271.06', 'stars': 1, 'title': 'Dell Latitude 54...'},
#  {'price': '$1273.11', 'stars': 3, 'title': 'Hewlett Packard...'},
#  {'price': '$1281.99', 'stars': 3, 'title': 'Dell XPS 13'},
#  {'price': '$1294.74', 'stars': 1, 'title': 'Toshiba Portege...'},
#  {'price': '$1299.00', 'stars': 3, 'title': 'MSI GL62VR 7RFX'},
#  {'price': '$1310.39', 'stars': 3, 'title': 'Dell Latitude 54...'},
#  {'price': '$1311.99', 'stars': 3, 'title': 'ThinkPad X240'},
#  {'price': '$1326.83', 'stars': 1, 'title': 'Hewlett Packard...'},
#  {'price': '$1333.00', 'stars': 1, 'title': 'Apple MacBook Pr...'},
#  {'price': '$1337.28', 'stars': 1, 'title': 'Dell Latitude 55...'},
#  {'price': '$1338.37', 'stars': 2, 'title': 'Dell Latitude 54...'},
#  {'price': '$1341.22', 'stars': 3, 'title': 'Dell Latitude 55...'},
#  {'price': '$1347.78', 'stars': 2, 'title': 'Apple MacBook Ai...'},
#  {'price': '$1349.23', 'stars': 1, 'title': 'Lenovo ThinkPad...'},
#  {'price': '$1362.24', 'stars': 2, 'title': 'Lenovo ThinkPad...'},
#  {'price': '$1366.32', 'stars': 1, 'title': 'Toshiba Portege...'},
#  {'price': '$1381.13', 'stars': 1, 'title': 'Asus ASUSPRO B94...'},
#  {'price': '$1399.00', 'stars': 3, 'title': 'Lenovo Legion Y7...'},
#  {'price': '$1399.00', 'stars': 3, 'title': 'Asus ROG Strix G...'},
#  {'price': '$1769.00', 'stars': 4, 'title': 'Asus ROG Strix G...'},
#  {'price': '$1769.00', 'stars': 1, 'title': 'Asus ROG Strix G...'},
#  {'price': '$1799.00', 'stars': 3, 'title': 'Asus ROG Strix S...'},
#  {'price': '$69.99', 'stars': 3, 'title': 'Lenovo IdeaTab'},
#  {'price': '$88.99', 'stars': 4, 'title': 'IdeaTab A3500L'},
#  {'price': '$96.99', 'stars': 1, 'title': 'Acer Iconia'},
#  {'price': '$97.99', 'stars': 2, 'title': 'Galaxy Tab 3'},
#  {'price': '$99.99', 'stars': 3, 'title': 'Iconia B1-730HD'},
#  {'price': '$101.99', 'stars': 2, 'title': 'Memo Pad HD 7'},
#  {'price': '$102.99', 'stars': 4, 'title': 'Asus MeMO Pad'},
#  {'price': '$103.99', 'stars': 4, 'title': 'Amazon Kindle'},
#  {'price': '$107.99', 'stars': 2, 'title': 'Galaxy Tab 3'},
#  {'price': '$121.99', 'stars': 2, 'title': 'IdeaTab A8-50'},
#  {'price': '$130.99', 'stars': 1, 'title': 'MeMO Pad 7'},
#  {'price': '$148.99', 'stars': 2, 'title': 'IdeaTab A3500-H'},
#  {'price': '$172.99', 'stars': 3, 'title': 'IdeaTab S5000'},
#  {'price': '$233.99', 'stars': 4, 'title': 'Galaxy Tab 4'},
#  {'price': '$251.99', 'stars': 3, 'title': 'Galaxy Tab'},
#  {'price': '$320.99', 'stars': 2, 'title': 'MeMo PAD FHD 10'},
#  {'price': '$399.99', 'stars': 4, 'title': 'Galaxy Note'},
#  {'price': '$489.99', 'stars': 3, 'title': 'Galaxy Note'},
#  {'price': '$537.99', 'stars': 2, 'title': 'iPad Mini Retina'},
#  {'price': '$587.99', 'stars': 2, 'title': 'Galaxy Note 10.1'},
#  {'price': '$603.99', 'stars': 3, 'title': 'Apple iPad Air'},
#  {'price': '$24.99', 'stars': 3, 'title': 'Nokia 123'},
#  {'price': '$57.99', 'stars': 3, 'title': 'LG Optimus'},
#  {'price': '$93.99', 'stars': 3, 'title': 'Samsung Galaxy'},
#  {'price': '$109.99', 'stars': 4, 'title': 'Nokia X'},
#  {'price': '$118.99', 'stars': 1, 'title': 'Sony Xperia'},
#  {'price': '$499.99', 'stars': 1, 'title': 'Ubuntu Edge'},
#  {'price': '$899.99', 'stars': 1, 'title': 'Iphone'},
#  {'price': '$899.99', 'stars': 2, 'title': 'Iphone'},
#  {'price': '$899.99', 'stars': 1, 'title': 'Iphone'}]
